# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Rana554/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# Refresh / Content Opportunity Scoring
#
# The important idea is:
#
# There are many pages, but a team has limited time. Data could help prioritize which pages deserve human review first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# Decision: My work will help prioritize which content pages should be reviewed first for possible refresh, improvement, or monitoring.
#
# Who acts on it: Content and SEO teams can use the ranked recommendations to decide which pages deserve human review.
#
# Cost of a wrong recommendation: A false positive could waste the team's limited time on a page that does not need attention. A false negative could cause an important page to be overlooked, potentially missing an opportunity to protect or improve its search performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# !git clone https://github.com/Rana554/flyrank-ml-internship.git
import os
import pandas as pd

print(os.listdir("/content"))


df = pd.read_csv(
    "/content/flyrank-ml-internship/data/raw/content_refresh_anonymized.csv"
)

print(df.shape)
num_pages = df["content_id"].nunique()

print("Number of unique pages:", num_pages)

declining = (df["trend_direction"] == "down").sum()

print("Pages with a downward trend:", declining)
print("Percentage declining:", round(declining / len(df) * 100, 2), "%")

visible = (df["impressions_90d"] >= 500).sum()

print("Pages with at least 500 impressions:", visible)
print("Percentage:", round(visible / len(df) * 100, 2), "%")
# Out:
# ['.config', 'flyrank-ml-internship', 'sample_data']
# (30000, 44)
# Number of unique pages: 30000
# Pages with a downward trend: 16262
# Percentage declining: 54.21 %
# Pages with at least 500 impressions: 16726
# Percentage: 55.75 %

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# What my work can say
#
# My work will provide decision-support by identifying pages that may deserve review based on observable search and content signals. It can show directional patterns between these signals and page performance, and help rank pages for human review.
#
# What my work cannot say
#
# My work will not prove that a specific change to a page caused its performance to improve. It will not prove Google's ranking algorithm or predict how Google will rank a page in the future. A high score will indicate that a page may be worth reviewing, not that refreshing it will definitely improve its performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
